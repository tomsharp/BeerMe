# %%
rand_state = 12

# %%
from BeerMe.Pipeline import *

# %%
df = import_table(db_path='data/beer.db')
df = df[['username', 'beer_name', 'beer_description', 'brewery', 'ABV', 'IBU', 'global_rating', 'user_rating']]
df.head()
# Out:
#   username                   beer_name         beer_description  \
# 0      tnt       Society & Solitude #7  IPA - Imperial / Double
# 1      tnt  Riwaka Single Hop Pale Ale      Pale Ale - American
# 2      tnt             Walk, Don't Run               Blonde Ale
# 3      tnt                   Czech Two          Pilsner - Czech
# 4      tnt            Spirit of Revolt  IPA - Imperial / Double
#
#                       brewery  ABV   IBU  global_rating  user_rating
# 0      Hill Farmstead Brewery  8.0  None           4.38         4.25
# 1      Hill Farmstead Brewery  5.2  None           4.14         5.00
# 2       Suarez Family Brewery  3.7  None           4.10         4.50
# 3          Gravely Brewing Co  4.1    39           3.81         4.25
# 4  Revolution Brewing Company  8.2    52           3.82         4.00

# %%
impute_method = 'mean'
for feature in features:
    if impute_method == 'mean':
        non_nas = df[~df[feature].isna()][feature].astype(float)
        feature_mean = non_nas.mean()
        df[feature] = df[feature].fillna(feature_mean)
    elif impute_method == 0:
        non_nas = df[~df[feature].isna()][feature].astype(float)
        df[feature] = df[feature].fillna(0)
    
print("NA Count...")
print(df.loc[:,features].isna().sum())
# Out:
# NA Count...
# ABV              0
# global_rating    0
# user_rating      0
# IBU              0
# dtype: int64

# %%
df.head()
# Out:
#   username                   beer_name         beer_description  \
# 0      tnt       Society & Solitude #7  IPA - Imperial / Double
# 1      tnt  Riwaka Single Hop Pale Ale      Pale Ale - American
# 2      tnt             Walk, Don't Run               Blonde Ale
# 3      tnt                   Czech Two          Pilsner - Czech
# 4      tnt            Spirit of Revolt  IPA - Imperial / Double
#
#                       brewery  ABV      IBU  global_rating  user_rating
# 0      Hill Farmstead Brewery  8.0  44.1594           4.38         4.25
# 1      Hill Farmstead Brewery  5.2  44.1594           4.14         5.00
# 2       Suarez Family Brewery  3.7  44.1594           4.10         4.50
# 3          Gravely Brewing Co  4.1       39           3.81         4.25
# 4  Revolution Brewing Company  8.2       52           3.82         4.00

# %% [markdown]
# # Cleaning Pipeline

# %%
from BeerMe.Pipeline import *

# %%
df = IMPORT_CLEAN_STEP(db_path='data/beer.db')
# Out:
# 1. NA Count...
# ABV                923
# global_rating        0
# user_rating       3882
# IBU              47035
# dtype: int64
#
#
# 2. Finding IQR outliers...
# FEATURE ABV
# num of outliers = 3,421
# % of outliers = 3.33%
#
#
# NA Count...
# ABV              0
# global_rating    0
# user_rating      0
# IBU              0
# dtype: int64

# %%
df = df[['username', 'beer_name', 'beer_description', 'brewery', 'ABV', 'IBU', 'global_rating', 'user_rating']]

# %%
df.head()
# Out:
#   username                   beer_name         beer_description  \
# 0      tnt       Society & Solitude #7  IPA - Imperial / Double
# 1      tnt  Riwaka Single Hop Pale Ale      Pale Ale - American
# 2      tnt             Walk, Don't Run               Blonde Ale
# 3      tnt                   Czech Two          Pilsner - Czech
# 4      tnt            Spirit of Revolt  IPA - Imperial / Double
#
#                       brewery  ABV      IBU  global_rating  user_rating
# 0      Hill Farmstead Brewery  8.0  44.1594           4.38         4.25
# 1      Hill Farmstead Brewery  5.2  44.1594           4.14         5.00
# 2       Suarez Family Brewery  3.7  44.1594           4.10         4.50
# 3          Gravely Brewing Co  4.1       39           3.81         4.25
# 4  Revolution Brewing Company  8.2       52           3.82         4.00

# %% [markdown]
# # 0. Baseline - Average

# %%
def baseline(df, user_of_interest):
    global_mean = np.mean(df['user_rating'])
    print("Global user_rating mean = {:.2f}".format(global_mean))
    beer_list = list(df[df['username']=='tsharp93']['beer_name'])
    
    estimated_rating_list = []
    error_list = []
    for beer in beer_list:
        try:
            estimated_rating = global_mean
            estimated_rating_list.append(estimated_rating)

            user_rating = df[(df['username']=='tsharp93') & (df['beer_name']==beer)]['user_rating'].iloc[0].astype(float)
            error_list.append(estimated_rating-user_rating)
        except IndexError:
            print(beer)
    mse = np.mean(np.array(error_list)**2)
    mae = np.absolute(error_list).mean()
    quarter_error_perc = 100 * np.sum(np.absolute(error_list) < 0.25) / len(error_list)
    half_error_perc = 100 * np.sum(np.absolute(error_list) < 0.50) / len(error_list)

    print("MSE = {:.2f}".format(mse))
    print("MAE = {:.2f}".format(mae))
    print("Errors within 0.25 = {:.2f} %".format(quarter_error_perc))
    print("Errors within 0.50 = {:.2f} %".format(half_error_perc))
    
    return mae, quarter_error_perc, half_error_perc

# %% [markdown]
# # 1. (Semi) Cold Start - Collaborative Filtering

# %% [markdown]
# ### For use when a user does not have enough data to build a model for his/her preferences

# %%
def cold_start(df, user_of_interest):
    try:
        df.drop('nearest_neighbor_rank', axis=1, inplace=True)
    except:
        pass
    df = COSINE_STEP(df, user_of_interest)
    beer_list = list(df[df['username']=='tsharp93']['beer_name'])
    estimated_rating_list = []
    error_list = []
    for beer in beer_list:
        try:
            estimated_rating = df[ (df.sort_values('nearest_neighbor_rank')['beer_name'] == beer) & (df['username']!=user_of_interest) ]['user_rating'].iloc[0]
            estimated_rating_list.append(estimated_rating)

            user_rating = df[(df['username']=='tsharp93') & (df['beer_name']==beer)]['user_rating'].iloc[0].astype(float)
            error_list.append(estimated_rating-user_rating)
        except IndexError:
            print("SKIPPING:", beer)
    mse = np.mean(np.array(error_list)**2)
    mae = np.absolute(error_list).mean()
    quarter_error_perc = 100 * np.sum(np.absolute(error_list) < 0.25) / len(error_list)
    half_error_perc = 100 * np.sum(np.absolute(error_list) < 0.50) / len(error_list)

    print("MSE = {:.2f}".format(mse))
    print("MAE = {:.2f}".format(mae))
    print("Errors within 0.25 = {:.2f} %".format(quarter_error_perc))
    print("Errors within 0.50 = {:.2f} %".format(half_error_perc))
    
    return mae, quarter_error_perc, half_error_perc

# %% [markdown]
# #### Problems with this approach:
# #### (1) Need another user to have the beer I have selected. If I want to get my user_rating for a beer that no one has tried, I can't do that.
# #### (2) Not very accurate. Almost half the points are outside of 0.5 error - sometimes worse than baseline

# %% [markdown]
# # 2. Content Based Filtering

# %% [markdown]
# ### *Assumes the user of interest has enough data to build a model

# %%
def run_model(df, user_of_interest, target):
    
    user_df = df
        
    features = list(df.columns[df.columns != target])
    print("FEATURES ", features[:10])
    print("TARGET ", target)
  
    from sklearn.model_selection import train_test_split
    X_train, X_test, y_train, y_test = train_test_split(df[features], user_df[target], random_state=rand_state)
    from sklearn.linear_model import LassoCV
    lassocv = LassoCV(fit_intercept=True, normalize=True, cv=5, random_state=rand_state)
    lassocv.fit(X_train, y_train)
    from sklearn.linear_model import Lasso
    lasso = Lasso(alpha=lassocv.alpha_,fit_intercept=True, normalize=True, random_state=rand_state)
    lasso.fit(X_train, y_train)
    
    coef_dropped_perc = 100*np.sum(lasso.coef_ == 0) / len(lasso.coef_)
    print("Percentage of estimators dropped = {:.2f} %".format(coef_dropped_perc))
    
    preds = lasso.predict(X_test)
    error_list = preds - y_test
    mse = np.mean(np.array(error_list)**2)
    mae = np.absolute(error_list).mean()
    quarter_error_perc = 100 * np.sum(np.absolute(error_list) < 0.25) / len(error_list)
    half_error_perc = 100 * np.sum(np.absolute(error_list) < 0.50) / len(error_list)
    print("MSE = {:.2f}".format(mse))
    print("MAE = {:.2f}".format(mae))
    print("Errors within 0.25 = {:.2f} %".format(quarter_error_perc))
    print("Errors within 0.50 = {:.2f} %".format(half_error_perc))
    
    return mae, quarter_error_perc, half_error_perc

# %% [markdown]
# ### A. Encoding Beer Description

# %%
def cat_encoding(df, encoding_col, drop_cols):

    df = convert_categorical(df, [encoding_col])
    df.drop(encoding_col, axis=1, inplace=True)
    df.drop(drop_cols, axis=1, inplace=True)
    
    return df

# %% [markdown]
# ##### Improved Accuracy over both Cold Start and Baseline

# %% [markdown]
# ### B. NLP (Count Vectorizer)

# %%
def count_vectorizer(df, vectoring_col, drop_cols):

    from sklearn.feature_extraction.text import CountVectorizer
    vect = CountVectorizer()
    X = vect.fit_transform(df[vectoring_col])
    tfidf_df = pd.DataFrame(X.toarray(), columns=vect.get_feature_names())
    df = pd.concat([df.reset_index(drop=True), tfidf_df], axis=1)
    
    df.drop(vectoring_col, axis=1, inplace=True)
    df.drop(drop_cols, axis=1, inplace=True)
    
    return df

# %% [markdown]
# ### C. NLP (TFIDF)

# %%
def tfidf_vectorizer(df, vectoring_col, drop_cols):
    
    from sklearn.feature_extraction.text import TfidfVectorizer
    vect = TfidfVectorizer()
    X = vect.fit_transform(df[vectoring_col])
    tfidf_df = pd.DataFrame(X.toarray(), columns=vect.get_feature_names())
    df = pd.concat([df.reset_index(drop=True), tfidf_df], axis=1)
    
    df.drop(vectoring_col, axis=1, inplace=True)
    df.drop(drop_cols, axis=1, inplace=True)
    
    return df

# %% [markdown]
# # 3. Hybrid

# %% [markdown]
# ### More Data

# %%
def hybrid(df, user_of_interest, target):
    
    features = list(df.columns[df.columns != target])
    features.remove('username')
    features.remove('beer_name')
    print("FEATURES ", features[:10])
    print('\n')
    print("TARGET ", target)
    print('\n')
    
    try:
        df.drop('nearest_neighbor_rank', axis=1, inplace=True)
    except:
        pass
    df = COSINE_STEP(df, user_of_interest)

    min_ppu_list = [0, 50, 100, 250, 500, 750, 1000]
    n_users_list = [5, 10, 15, 20, 25, 30, 35, 40, 45, 50, 
                    55, 60, 65, 70, 75, 80, 85, 100, len(df['username'].unique())-1]

    mae_list = []
    quarter_abs_error_list = []
    half_abs_error_list = []


    for min_ppu in min_ppu_list:

        user_indices = df.username.value_counts()[df.username.value_counts() > min_ppu].index
        sub_df = df[df['username'].isin(user_indices)]
        n_users_list = [n_users for n_users in n_users_list if n_users < len(user_indices)]

        for top_n in n_users_list:

            # split data 
            top_n_nn = list(sub_df['nearest_neighbor_rank'].unique())[:top_n]
            df_top_n = df[df['nearest_neighbor_rank'].isin(top_n_nn)]
            X_train = df_top_n[features]
            y_train = df_top_n[target]
            y_train = np.array(y_train).reshape(len(y_train), )

            X_test = df[df['username'] == user_of_interest][features]
            y_test = df[df['username'] == user_of_interest][target]
            y_test = np.array(y_test).reshape(len(y_test), )

            # train
            from sklearn.linear_model import LassoCV
            model = LassoCV(fit_intercept=True, normalize=True, cv=5, random_state=rand_state)
            model.fit(X_train, y_train)

            # Evaluate model on user's data 
            preds = model.predict(X_test)

            # evaluate results
            results_df = pd.DataFrame([preds, y_test]).transpose()
            results_df.columns = ['predicted', 'actual']
            results_df['error'] = results_df['predicted'] - results_df['actual']
            results_df['abs_error'] = abs(results_df['error'])

            # Performance Metrics 
            mae = np.mean(results_df['abs_error'])

            quarter_abs_error_list.append(100*len(results_df[results_df['abs_error']<=0.25])/len(results_df))
            half_abs_error_list.append(100*len(results_df[results_df['abs_error']<=0.50])/len(results_df))
            mae_list.append(mae)

        # add breaks
        quarter_abs_error_list.append(0)
        half_abs_error_list.append(0)
        mae_list.append(0)
        
    return mae_list, min_ppu_list, n_users_list

# %%
def plot_hybrid(mae_list, min_ppu_list, n_users_list):
    # plot
    ls = mae_list

    size = len(ls) 
    idx_list = [idx + 1 for idx, val in enumerate(ls) if val == 0] 
    ys = [ls[i: j] for i, j in
            zip([0] + idx_list, idx_list + 
            ([size] if idx_list[-1] != size else []))] 

    for i, y in enumerate(ys):
        y = y[:-1]
        ys[i] = y

    import matplotlib.cm as cm
    colors = cm.rainbow(np.linspace(0, 1, len(ys)))

    plt.figure(figsize=[15,10])
    plt.title("ENet with Nearest Neighbors and Min_PPU")
    plt.xlabel("N Nearest Neighbors")
    plt.ylabel("MAE")

    i = 0
    for y, c in zip(ys, colors):
        x = np.linspace(5, 5*len(y), len(y))
        if i == 0:
            x = [5, 10, 15, 20, 25, 30, 35, 40, 45, 50, 55, 60, 65, 70, 75, 80, 85, 100, len(df['username'].unique())-1]
        else:
            x = np.linspace(5, 5*len(y), len(y))
        plt.scatter(x, y, color=c, label="Min PPU = " + str(min_ppu_list[i]))
        i += 1

    plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
    plt.show()

# %% [markdown]
# # Putting it all together

# %%
df.head()
# Out:
#   username                   beer_name         beer_description  \
# 0      tnt       Society & Solitude #7  IPA - Imperial / Double
# 1      tnt  Riwaka Single Hop Pale Ale      Pale Ale - American
# 2      tnt             Walk, Don't Run               Blonde Ale
# 3      tnt                   Czech Two          Pilsner - Czech
# 4      tnt            Spirit of Revolt  IPA - Imperial / Double
#
#                       brewery  ABV      IBU  global_rating  user_rating
# 0      Hill Farmstead Brewery  8.0  44.1594           4.38         4.25
# 1      Hill Farmstead Brewery  5.2  44.1594           4.14         5.00
# 2       Suarez Family Brewery  3.7  44.1594           4.10         4.50
# 3          Gravely Brewing Co  4.1       39           3.81         4.25
# 4  Revolution Brewing Company  8.2       52           3.82         4.00

# %% [markdown]
# #### Less Data

# %%
user_of_interest = 'tsharp93'

# %%
drop_cols =['username', 'beer_name', 'brewery']

### - BASELINE - ###
print("BASELINE")
baseline(df, user_of_interest)


### - CONTENT BASED FILTERING - ###
print("\n")
print("CONTENT BASED FILTERING")
print("simple - contin. vars only")
user_df = df[df['username']==user_of_interest].drop(drop_cols + ['beer_description'], axis=1, inplace=False)
run_model(user_df, user_of_interest, 'user_rating')

print("categorical encoding")
user_df = cat_encoding(df, 'beer_description', drop_cols)
run_model(user_df, user_of_interest, 'user_rating')

print("\n")
print("count vectorizer")
user_df = count_vectorizer(df,'beer_description', drop_cols)
run_model(user_df, user_of_interest, 'user_rating')

print("\n")
print("tfidf vectorizer")
user_df = tfidf_vectorizer(df,'beer_description', drop_cols)
run_model(user_df, user_of_interest, 'user_rating')


### - COLD START - ###
print("\n")
print("(SEMI) COLD START - COLLABORATIVE FILTERING")
cold_start(df, user_of_interest)


### - HYBRID - ###
drop_cols = ['brewery']

print("HYBRID")
print("\n")
print("simple - contin. vars only")
hybrid_df = df.drop(drop_cols + ['beer_description'], axis=1, inplace=False)
mae_list, min_ppu_list, n_users_list = hybrid(hybrid_df, user_of_interest, 'user_rating')
plot_hybrid(mae_list, min_ppu_list, n_users_list)

print("\n")
print("categorical encoding")
hybrid_df = cat_encoding(df, 'beer_description', drop_cols)
mae_list, min_ppu_list, n_users_list = hybrid(hybrid_df, user_of_interest, 'user_rating')
plot_hybrid(mae_list, min_ppu_list, n_users_list)

print("\n")
print("count vectorizer")
hybrid_df = count_vectorizer(df, 'beer_description', drop_cols)
mae_list, min_ppu_list, n_users_list = hybrid(hybrid_df, user_of_interest, 'user_rating')
plot_hybrid(mae_list, min_ppu_list, n_users_list)

print("\n")
print("tfidf vectorizer")
hybrid_df= tfidf_vectorizer(df,'beer_description', drop_cols)
mae_list, min_ppu_list, n_users_list = hybrid(hybrid_df, user_of_interest, 'user_rating')
plot_hybrid(mae_list, min_ppu_list, n_users_list)
# Out:
# BASELINE
# Global user_rating mean = 3.71
# MSE = 0.23
# MAE = 0.40
# Errors within 0.25 = 35.00 %
# Errors within 0.50 = 67.50 %
#
#
# (SEMI) COLD START - COLLABORATIVE FILTERING
# User of Reference for Cosine Sim = tsharp93
# SKIPPING: Sig Sour 6.5
# SKIPPING: The Drongo
# SKIPPING: They Both Melt
# SKIPPING: Black Matter
# SKIPPING: The Caucasian
# SKIPPING: Caturro Coffee Cream Ale
# SKIPPING: Shiner Day Quencher
# SKIPPING: Barrel-Aged 4Beans
# SKIPPING: Marionberry Lavender Sour Ale
# SKIPPING: Southern Torrent Saison
# SKIPPING: The Drongo
# SKIPPING: They Both Melt
# MSE = 0.27
# MAE = 0.38
# Errors within 0.25 = 35.71 %
# Errors within 0.50 = 53.57 %
#
#
# CONTENT BASED FILTERING
# simple - contin. vars only
# FEATURES  ['ABV', 'IBU', 'global_rating']
# TARGET  user_rating
# Percentage of estimators dropped = 33.33 %
# MSE = 0.12
# MAE = 0.31
# Errors within 0.25 = 30.00 %
# Errors within 0.50 = 90.00 %
# categorical encoding
# FEATURES  ['ABV', 'IBU', 'global_rating', 'beer_description_Adambier', 'beer_description_Altbier', 'beer_description_American Wild Ale', 'beer_description_Australian Sparkling Ale', 'beer_description_Barleywine - American', 'beer_description_Barleywine - English', 'beer_description_Barleywine - Other']
# TARGET  user_rating
# Percentage of estimators dropped = 15.57 %
# MSE = 0.31
# MAE = 0.41
# Errors within 0.25 = 42.09 %
# Errors within 0.50 = 70.83 %
#
#
# count vectorizer
# FEATURES  ['ABV', 'IBU', 'global_rating', 'abbey', 'adambier', 'alcoholic', 'ale', 'altbier', 'amber', 'american']
# TARGET  user_rating
# Percentage of estimators dropped = 22.22 %
# MSE = 0.31
# MAE = 0.41
# Errors within 0.25 = 42.19 %
# Errors within 0.50 = 70.73 %
#
#
# tfidf vectorizer
# FEATURES  ['ABV', 'IBU', 'global_rating', 'abbey', 'adambier', 'alcoholic', 'ale', 'altbier', 'amber', 'american']
# TARGET  user_rating
# Percentage of estimators dropped = 25.93 %
# MSE = 0.31
# MAE = 0.41
# Errors within 0.25 = 42.27 %
# Errors within 0.50 = 70.77 %
#
#
# HYBRID
# simple - contin. vars only
# FEATURES  ['ABV', 'IBU', 'global_rating']
#
#
# TARGET  user_rating
#
#
# User of Reference for Cosine Sim = tsharp93
# categorical encoding
# FEATURES  ['ABV', 'IBU', 'global_rating', 'beer_description_Adambier', 'beer_description_Altbier', 'beer_description_American Wild Ale', 'beer_description_Australian Sparkling Ale', 'beer_description_Barleywine - American', 'beer_description_Barleywine - English', 'beer_description_Barleywine - Other']
#
#
# TARGET  user_rating
#
#
# User of Reference for Cosine Sim = tsharp93
# count vectorizer
# FEATURES  ['ABV', 'IBU', 'global_rating', 'abbey', 'adambier', 'alcoholic', 'ale', 'altbier', 'amber', 'american']
#
#
# TARGET  user_rating
#
#
# User of Reference for Cosine Sim = tsharp93
# tfidf vectorizer
# FEATURES  ['ABV', 'IBU', 'global_rating', 'abbey', 'adambier', 'alcoholic', 'ale', 'altbier', 'amber', 'american']
#
#
# TARGET  user_rating
#
#
# User of Reference for Cosine Sim = tsharp93

# %% [markdown]
# #### More Data

# %%
user_of_interest = 'tnt'

# %%
drop_cols =['username', 'beer_name', 'brewery']

### - BASELINE - ###
print("BASELINE")
baseline(df, user_of_interest)


### - CONTENT BASED FILTERING - ###
print("\n")
print("CONTENT BASED FILTERING")
print("simple - contin. vars only")
user_df = df[df['username']==user_of_interest].drop(drop_cols + ['beer_description'], axis=1, inplace=False)
run_model(user_df, user_of_interest, 'user_rating')

print("categorical encoding")
user_df = cat_encoding(df, 'beer_description', drop_cols)
run_model(user_df, user_of_interest, 'user_rating')

print("\n")
print("count vectorizer")
user_df = count_vectorizer(df,'beer_description', drop_cols)
run_model(user_df, user_of_interest, 'user_rating')

print("\n")
print("tfidf vectorizer")
user_df = tfidf_vectorizer(df,'beer_description', drop_cols)
run_model(user_df, user_of_interest, 'user_rating')


### - COLD START - ###
print("\n")
print("(SEMI) COLD START - COLLABORATIVE FILTERING")
cold_start(df, user_of_interest)


### - HYBRID - ###
drop_cols = ['brewery']

print("HYBRID")
print("\n")
print("simple - contin. vars only")
hybrid_df = df.drop(drop_cols + ['beer_description'], axis=1, inplace=False)
mae_list, min_ppu_list, n_users_list = hybrid(hybrid_df, user_of_interest, 'user_rating')
plot_hybrid(mae_list, min_ppu_list, n_users_list)

print("\n")
print("categorical encoding")
hybrid_df = cat_encoding(df, 'beer_description', drop_cols)
mae_list, min_ppu_list, n_users_list = hybrid(hybrid_df, user_of_interest, 'user_rating')
plot_hybrid(mae_list, min_ppu_list, n_users_list)

print("\n")
print("count vectorizer")
hybrid_df = count_vectorizer(df, 'beer_description', drop_cols)
mae_list, min_ppu_list, n_users_list = hybrid(hybrid_df, user_of_interest, 'user_rating')
plot_hybrid(mae_list, min_ppu_list, n_users_list)

print("\n")
print("tfidf vectorizer")
hybrid_df= tfidf_vectorizer(df,'beer_description', drop_cols)
mae_list, min_ppu_list, n_users_list = hybrid(hybrid_df, user_of_interest, 'user_rating')
plot_hybrid(mae_list, min_ppu_list, n_users_list)
# Out:
# BASELINE
# Global user_rating mean = 3.71
# MSE = 0.23
# MAE = 0.40
# Errors within 0.25 = 35.00 %
# Errors within 0.50 = 67.50 %
#
#
# (SEMI) COLD START - COLLABORATIVE FILTERING
# User of Reference for Cosine Sim = tnt
# MSE = 0.33
# MAE = 0.38
# Errors within 0.25 = 42.50 %
# Errors within 0.50 = 55.00 %
#
#
# CONTENT BASED FILTERING
# simple - contin. vars only
# FEATURES  ['ABV', 'IBU', 'global_rating']
# TARGET  user_rating
# Percentage of estimators dropped = 0.00 %
# MSE = 0.27
# MAE = 0.39
# Errors within 0.25 = 46.08 %
# Errors within 0.50 = 72.21 %
# categorical encoding
# FEATURES  ['ABV', 'IBU', 'global_rating', 'beer_description_Adambier', 'beer_description_Altbier', 'beer_description_American Wild Ale', 'beer_description_Australian Sparkling Ale', 'beer_description_Barleywine - American', 'beer_description_Barleywine - English', 'beer_description_Barleywine - Other']
# TARGET  user_rating
# Percentage of estimators dropped = 15.57 %
# MSE = 0.31
# MAE = 0.41
# Errors within 0.25 = 42.09 %
# Errors within 0.50 = 70.83 %
#
#
# count vectorizer
# FEATURES  ['ABV', 'IBU', 'global_rating', 'abbey', 'adambier', 'alcoholic', 'ale', 'altbier', 'amber', 'american']
# TARGET  user_rating
# Percentage of estimators dropped = 22.22 %
# MSE = 0.31
# MAE = 0.41
# Errors within 0.25 = 42.19 %
# Errors within 0.50 = 70.73 %
#
#
# tfidf vectorizer
# FEATURES  ['ABV', 'IBU', 'global_rating', 'abbey', 'adambier', 'alcoholic', 'ale', 'altbier', 'amber', 'american']
# TARGET  user_rating
# Percentage of estimators dropped = 25.93 %
# MSE = 0.31
# MAE = 0.41
# Errors within 0.25 = 42.27 %
# Errors within 0.50 = 70.77 %
#
#
# HYBRID
# simple - contin. vars only
# FEATURES  ['ABV', 'IBU', 'global_rating']
#
#
# TARGET  user_rating
#
#
# User of Reference for Cosine Sim = tnt
# categorical encoding
# FEATURES  ['ABV', 'IBU', 'global_rating', 'beer_description_Adambier', 'beer_description_Altbier', 'beer_description_American Wild Ale', 'beer_description_Australian Sparkling Ale', 'beer_description_Barleywine - American', 'beer_description_Barleywine - English', 'beer_description_Barleywine - Other']
#
#
# TARGET  user_rating
#
#
# User of Reference for Cosine Sim = tnt
# count vectorizer
# FEATURES  ['ABV', 'IBU', 'global_rating', 'abbey', 'adambier', 'alcoholic', 'ale', 'altbier', 'amber', 'american']
#
#
# TARGET  user_rating
#
#
# User of Reference for Cosine Sim = tnt
# tfidf vectorizer
# FEATURES  ['ABV', 'IBU', 'global_rating', 'abbey', 'adambier', 'alcoholic', 'ale', 'altbier', 'amber', 'american']
#
#
# TARGET  user_rating
#
#
# User of Reference for Cosine Sim = tnt

# %% [markdown]
# ### Hybrid Statistical Significance

# %%
df = df[~df.duplicated()]
checkin_count = df.groupby('username').count()['beer_name']
checkin_count.columns = ['checkin_count']

# %%
low_checkins = checkin_count[(checkin_count < 25) & (checkin_count > 5)].index

# %%
high_checkins = checkin_count[checkin_count > 1000].index

# %%
low_indices = np.random.choice(len(low_checkins), 10, replace=False)
high_indices = np.random.choice(len(high_checkins), 10, replace=False)

# %%
d={}
for i in low_indices:
    
    user_of_interest = low_checkins[i]
    print("USER OF INTEREST", user_of_interest)

    drop_cols =['username', 'beer_name', 'brewery']
    ### - BASELINE - ###
    print("BASELINE")
    baseline_mae, _, _ = baseline(df, user_of_interest)
   
    ### - CONTENT BASED FILTERING - ###
    print("\n")
    print("CONTENT BASED FILTERING")
    print("simple - contin. vars only")
    user_df = df[df['username']==user_of_interest].drop(drop_cols + ['beer_description'], axis=1, inplace=False)
    cbf_mae, _, _ = run_model(user_df, user_of_interest, 'user_rating')
    

    ### - COLD START - ###
    print("\n")
    print("(SEMI) COLD START - COLLABORATIVE FILTERING")
    cf_mae, _, _ = cold_start(df, user_of_interest)

    ### - HYBRID - ###
    drop_cols = ['brewery']
    print("HYBRID")
    print("\n")
    print("simple - contin. vars only")
    hybrid_df = df.drop(drop_cols + ['beer_description'], axis=1, inplace=False)
    mae_list, min_ppu_list, n_users_list = hybrid(hybrid_df, user_of_interest, 'user_rating')
#     plot_hybrid(mae_list, min_ppu_list, n_users_list)
    hybrid_mae = np.min([mae for mae in mae_list if mae != 0.0])
    
    d[user_of_interest] = {'baseline': baseline_mae, 'cbf': cbf_mae, 'cf': cf_mae, 'hybrid': hybrid_mae, 'group':'low_checkins'}

for i in high_indices:
    
    user_of_interest = high_checkins[i]
    print("USER OF INTEREST", user_of_interest)

    drop_cols =['username', 'beer_name', 'brewery']
    ### - BASELINE - ###
    print("BASELINE")
    baseline_mae, _, _ = baseline(df, user_of_interest)
    d[user_of_interest] = {'min_mae': baseline_mae, 'method':'baseline', 'group':'high_checkins'}

    ### - CONTENT BASED FILTERING - ###
    print("\n")
    print("CONTENT BASED FILTERING")
    print("simple - contin. vars only")
    user_df = df[df['username']==user_of_interest].drop(drop_cols + ['beer_description'], axis=1, inplace=False)
    cbf_mae, _, _ = run_model(user_df, user_of_interest, 'user_rating')
    d[user_of_interest] = {'min_mae': cbf_mae, 'method':'CBF', 'group':'high_checkins'}

    ### - COLD START - ###
    print("\n")
    print("(SEMI) COLD START - COLLABORATIVE FILTERING")
    cf_mae, _, _ = cold_start(df, user_of_interest)
    d[user_of_interest] = {'min_mae': cf_mae, 'method':'CF', 'group':'high_checkins'}

    ### - HYBRID - ###
    drop_cols = ['brewery']
    print("HYBRID")
    print("\n")
    print("simple - contin. vars only")
    hybrid_df = df.drop(drop_cols + ['beer_description'], axis=1, inplace=False)
    mae_list, min_ppu_list, n_users_list = hybrid(hybrid_df, user_of_interest, 'user_rating')
#     plot_hybrid(mae_list, min_ppu_list, n_users_list)
    hybrid_mae = np.min([mae for mae in mae_list if mae != 0.0])
    
    d[user_of_interest] = {'baseline': baseline_mae, 'cbf': cbf_mae, 'cf': cf_mae, 'hybrid': hybrid_mae, 'group':'high_checkins'}
# Out:
# USER OF INTEREST Fujimike
# BASELINE
# Global user_rating mean = 3.71
# MSE = 0.23
# MAE = 0.40
# Errors within 0.25 = 35.00 %
# Errors within 0.50 = 67.50 %
#
#
# CONTENT BASED FILTERING
# simple - contin. vars only
# FEATURES  ['ABV', 'IBU', 'global_rating']
# TARGET  user_rating
# Percentage of estimators dropped = 66.67 %
# MSE = 0.36
# MAE = 0.52
# Errors within 0.25 = 25.00 %
# Errors within 0.50 = 50.00 %
#
#
# (SEMI) COLD START - COLLABORATIVE FILTERING
# User of Reference for Cosine Sim = Fujimike
# MSE = 0.23
# MAE = 0.33
# Errors within 0.25 = 47.50 %
# Errors within 0.50 = 55.00 %
# HYBRID
#
#
# simple - contin. vars only
# FEATURES  ['ABV', 'IBU', 'global_rating']
#
#
# TARGET  user_rating
#
#
# User of Reference for Cosine Sim = Fujimike
# USER OF INTEREST insertcoxjokehere
# BASELINE
# Global user_rating mean = 3.71
# MSE = 0.23
# MAE = 0.40
# Errors within 0.25 = 35.00 %
# Errors within 0.50 = 67.50 %
#
#
# CONTENT BASED FILTERING
# simple - contin. vars only
# FEATURES  ['ABV', 'IBU', 'global_rating']
# TARGET  user_rating
# Percentage of estimators dropped = 0.00 %
# MSE = 0.40
# MAE = 0.55
# Errors within 0.25 = 16.67 %
# Errors within 0.50 = 50.00 %
#
#
# (SEMI) COLD START - COLLABORATIVE FILTERING
# User of Reference for Cosine Sim = insertcoxjokehere
# MSE = 0.31
# MAE = 0.38
# Errors within 0.25 = 47.50 %
# Errors within 0.50 = 52.50 %
# HYBRID
#
#
# simple - contin. vars only
# FEATURES  ['ABV', 'IBU', 'global_rating']
#
#
# TARGET  user_rating
#
#
# User of Reference for Cosine Sim = insertcoxjokehere
# USER OF INTEREST Justinswaldrip
# BASELINE
# Global user_rating mean = 3.71
# MSE = 0.23
# MAE = 0.40
# Errors within 0.25 = 35.00 %
# Errors within 0.50 = 67.50 %
#
#
# CONTENT BASED FILTERING
# simple - contin. vars only
# FEATURES  ['ABV', 'IBU', 'global_rating']
# TARGET  user_rating
# Percentage of estimators dropped = 100.00 %
# MSE = 0.00
# MAE = 0.03
# Errors within 0.25 = 100.00 %
# Errors within 0.50 = 100.00 %
#
#
# (SEMI) COLD START - COLLABORATIVE FILTERING
# User of Reference for Cosine Sim = Justinswaldrip
# MSE = 0.24
# MAE = 0.31
# Errors within 0.25 = 50.00 %
# Errors within 0.50 = 65.00 %
# HYBRID
#
#
# simple - contin. vars only
# FEATURES  ['ABV', 'IBU', 'global_rating']
#
#
# TARGET  user_rating
#
#
# User of Reference for Cosine Sim = Justinswaldrip
# USER OF INTEREST tamarawolfson
# BASELINE
# Global user_rating mean = 3.71
# MSE = 0.23
# MAE = 0.40
# Errors within 0.25 = 35.00 %
# Errors within 0.50 = 67.50 %
#
#
# CONTENT BASED FILTERING
# simple - contin. vars only
# FEATURES  ['ABV', 'IBU', 'global_rating']
# TARGET  user_rating
# Percentage of estimators dropped = 100.00 %
# MSE = 0.42
# MAE = 0.51
# Errors within 0.25 = 50.00 %
# Errors within 0.50 = 50.00 %
#
#
# (SEMI) COLD START - COLLABORATIVE FILTERING
# User of Reference for Cosine Sim = tamarawolfson
# MSE = 0.22
# MAE = 0.30
# Errors within 0.25 = 47.50 %
# Errors within 0.50 = 65.00 %
# HYBRID
#
#
# simple - contin. vars only
# FEATURES  ['ABV', 'IBU', 'global_rating']
#
#
# TARGET  user_rating
#
#
# User of Reference for Cosine Sim = tamarawolfson
# USER OF INTEREST marcosten
# BASELINE
# Global user_rating mean = 3.71
# MSE = 0.23
# MAE = 0.40
# Errors within 0.25 = 35.00 %
# Errors within 0.50 = 67.50 %
#
#
# CONTENT BASED FILTERING
# simple - contin. vars only
# FEATURES  ['ABV', 'IBU', 'global_rating']
# TARGET  user_rating
# Percentage of estimators dropped = 0.00 %
# MSE = 0.18
# MAE = 0.41
# Errors within 0.25 = 0.00 %
# Errors within 0.50 = 100.00 %
#
#
# (SEMI) COLD START - COLLABORATIVE FILTERING
# User of Reference for Cosine Sim = marcosten
# MSE = 0.42
# MAE = 0.38
# Errors within 0.25 = 50.00 %
# Errors within 0.50 = 65.00 %
# HYBRID
#
#
# simple - contin. vars only
# FEATURES  ['ABV', 'IBU', 'global_rating']
#
#
# TARGET  user_rating
#
#
# User of Reference for Cosine Sim = marcosten
# USER OF INTEREST Audyoh
# BASELINE
# Global user_rating mean = 3.71
# MSE = 0.23
# MAE = 0.40
# Errors within 0.25 = 35.00 %
# Errors within 0.50 = 67.50 %
#
#
# CONTENT BASED FILTERING
# simple - contin. vars only
# FEATURES  ['ABV', 'IBU', 'global_rating']
# TARGET  user_rating
# Percentage of estimators dropped = 100.00 %
# MSE = 0.31
# MAE = 0.44
# Errors within 0.25 = 50.00 %
# Errors within 0.50 = 75.00 %
#
#
# (SEMI) COLD START - COLLABORATIVE FILTERING
# User of Reference for Cosine Sim = Audyoh
# MSE = 0.18
# MAE = 0.24
# Errors within 0.25 = 57.50 %
# Errors within 0.50 = 75.00 %
# HYBRID
#
#
# simple - contin. vars only
# FEATURES  ['ABV', 'IBU', 'global_rating']
#
#
# TARGET  user_rating
#
#
# User of Reference for Cosine Sim = Audyoh
# USER OF INTEREST thomasstorfjord
# BASELINE
# Global user_rating mean = 3.71
# MSE = 0.23
# MAE = 0.40
# Errors within 0.25 = 35.00 %
# Errors within 0.50 = 67.50 %
#
#
# CONTENT BASED FILTERING
# simple - contin. vars only
# FEATURES  ['ABV', 'IBU', 'global_rating']
# TARGET  user_rating
# Percentage of estimators dropped = 0.00 %
# MSE = 3.33
# MAE = 1.43
# Errors within 0.25 = 0.00 %
# Errors within 0.50 = 25.00 %
#
#
# (SEMI) COLD START - COLLABORATIVE FILTERING
# User of Reference for Cosine Sim = thomasstorfjord
# MSE = 0.21
# MAE = 0.29
# Errors within 0.25 = 50.00 %
# Errors within 0.50 = 62.50 %
# HYBRID
#
#
# simple - contin. vars only
# FEATURES  ['ABV', 'IBU', 'global_rating']
#
#
# TARGET  user_rating
#
#
# User of Reference for Cosine Sim = thomasstorfjord
# USER OF INTEREST cmosten
# BASELINE
# Global user_rating mean = 3.71
# MSE = 0.23
# MAE = 0.40
# Errors within 0.25 = 35.00 %
# Errors within 0.50 = 67.50 %
#
#
# CONTENT BASED FILTERING
# simple - contin. vars only
# FEATURES  ['ABV', 'IBU', 'global_rating']
# TARGET  user_rating
# Percentage of estimators dropped = 0.00 %
# MSE = 0.72
# MAE = 0.74
# Errors within 0.25 = 0.00 %
# Errors within 0.50 = 33.33 %
#
#
# (SEMI) COLD START - COLLABORATIVE FILTERING
# User of Reference for Cosine Sim = cmosten
# MSE = 0.50
# MAE = 0.45
# Errors within 0.25 = 45.00 %
# Errors within 0.50 = 60.00 %
# HYBRID
#
#
# simple - contin. vars only
# FEATURES  ['ABV', 'IBU', 'global_rating']
#
#
# TARGET  user_rating
#
#
# User of Reference for Cosine Sim = cmosten
# USER OF INTEREST Punk_Caste
# BASELINE
# Global user_rating mean = 3.71
# MSE = 0.23
# MAE = 0.40
# Errors within 0.25 = 35.00 %
# Errors within 0.50 = 67.50 %
#
#
# CONTENT BASED FILTERING
# simple - contin. vars only
# FEATURES  ['ABV', 'IBU', 'global_rating']
# TARGET  user_rating
# Percentage of estimators dropped = 100.00 %
# MSE = 0.03
# MAE = 0.19
# Errors within 0.25 = 100.00 %
# Errors within 0.50 = 100.00 %
#
#
# (SEMI) COLD START - COLLABORATIVE FILTERING
# User of Reference for Cosine Sim = Punk_Caste
# MSE = 0.40
# MAE = 0.39
# Errors within 0.25 = 47.50 %
# Errors within 0.50 = 62.50 %
# HYBRID
#
#
# simple - contin. vars only
# FEATURES  ['ABV', 'IBU', 'global_rating']
#
#
# TARGET  user_rating
#
#
# User of Reference for Cosine Sim = Punk_Caste
# USER OF INTEREST WhisKerfuffle
# BASELINE
# Global user_rating mean = 3.71
# MSE = 0.23
# MAE = 0.40
# Errors within 0.25 = 35.00 %
# Errors within 0.50 = 67.50 %
#
#
# CONTENT BASED FILTERING
# simple - contin. vars only
# FEATURES  ['ABV', 'IBU', 'global_rating']
# TARGET  user_rating
# Percentage of estimators dropped = 66.67 %
# MSE = 0.21
# MAE = 0.30
# Errors within 0.25 = 60.00 %
# Errors within 0.50 = 80.00 %
#
#
# (SEMI) COLD START - COLLABORATIVE FILTERING
# User of Reference for Cosine Sim = WhisKerfuffle
# MSE = 0.24
# MAE = 0.33
# Errors within 0.25 = 47.50 %
# Errors within 0.50 = 57.50 %
# HYBRID
#
#
# simple - contin. vars only
# FEATURES  ['ABV', 'IBU', 'global_rating']
#
#
# TARGET  user_rating
#
#
# User of Reference for Cosine Sim = WhisKerfuffle
# USER OF INTEREST iamthearrison
# BASELINE
# Global user_rating mean = 3.71
# MSE = 0.23
# MAE = 0.40
# Errors within 0.25 = 35.00 %
# Errors within 0.50 = 67.50 %
#
#
# CONTENT BASED FILTERING
# simple - contin. vars only
# FEATURES  ['ABV', 'IBU', 'global_rating']
# TARGET  user_rating
# Percentage of estimators dropped = 0.00 %
# MSE = 0.65
# MAE = 0.62
# Errors within 0.25 = 27.69 %
# Errors within 0.50 = 47.69 %
#
#
# (SEMI) COLD START - COLLABORATIVE FILTERING
# User of Reference for Cosine Sim = iamthearrison
# MSE = 0.29
# MAE = 0.31
# Errors within 0.25 = 47.50 %
# Errors within 0.50 = 70.00 %
# HYBRID
#
#
# simple - contin. vars only
# FEATURES  ['ABV', 'IBU', 'global_rating']
#
#
# TARGET  user_rating
#
#
# User of Reference for Cosine Sim = iamthearrison
# USER OF INTEREST marcusSRG
# BASELINE
# Global user_rating mean = 3.71
# MSE = 0.23
# MAE = 0.40
# Errors within 0.25 = 35.00 %
# Errors within 0.50 = 67.50 %
#
#
# CONTENT BASED FILTERING
# simple - contin. vars only
# FEATURES  ['ABV', 'IBU', 'global_rating']
# TARGET  user_rating
# Percentage of estimators dropped = 33.33 %
# MSE = 0.13
# MAE = 0.27
# Errors within 0.25 = 58.45 %
# Errors within 0.50 = 85.84 %
#
#
# (SEMI) COLD START - COLLABORATIVE FILTERING
# User of Reference for Cosine Sim = marcusSRG
# MSE = 0.35
# MAE = 0.40
# Errors within 0.25 = 35.00 %
# Errors within 0.50 = 55.00 %
# HYBRID
#
#
# simple - contin. vars only
# FEATURES  ['ABV', 'IBU', 'global_rating']
#
#
# TARGET  user_rating
#
#
# User of Reference for Cosine Sim = marcusSRG
# USER OF INTEREST thebigjohnson95
# BASELINE
# Global user_rating mean = 3.71
# MSE = 0.23
# MAE = 0.40
# Errors within 0.25 = 35.00 %
# Errors within 0.50 = 67.50 %
#
#
# CONTENT BASED FILTERING
# simple - contin. vars only
# FEATURES  ['ABV', 'IBU', 'global_rating']
# TARGET  user_rating
# Percentage of estimators dropped = 0.00 %
# MSE = 0.22
# MAE = 0.32
# Errors within 0.25 = 55.48 %
# Errors within 0.50 = 83.48 %
#
#
# (SEMI) COLD START - COLLABORATIVE FILTERING
# User of Reference for Cosine Sim = thebigjohnson95
# MSE = 0.33
# MAE = 0.36
# Errors within 0.25 = 40.00 %
# Errors within 0.50 = 62.50 %
# HYBRID
#
#
# simple - contin. vars only
# FEATURES  ['ABV', 'IBU', 'global_rating']
#
#
# TARGET  user_rating
#
#
# User of Reference for Cosine Sim = thebigjohnson95
# USER OF INTEREST dodson32
# BASELINE
# Global user_rating mean = 3.71
# MSE = 0.23
# MAE = 0.40
# Errors within 0.25 = 35.00 %
# Errors within 0.50 = 67.50 %
#
#
# CONTENT BASED FILTERING
# simple - contin. vars only
# FEATURES  ['ABV', 'IBU', 'global_rating']
# TARGET  user_rating
# Percentage of estimators dropped = 33.33 %
# MSE = 0.15
# MAE = 0.26
# Errors within 0.25 = 65.67 %
# Errors within 0.50 = 86.57 %
#
#
# (SEMI) COLD START - COLLABORATIVE FILTERING
# User of Reference for Cosine Sim = dodson32
# MSE = 0.20
# MAE = 0.31
# Errors within 0.25 = 42.50 %
# Errors within 0.50 = 62.50 %
# HYBRID
#
#
# simple - contin. vars only
# FEATURES  ['ABV', 'IBU', 'global_rating']
#
#
# TARGET  user_rating
#
#
# User of Reference for Cosine Sim = dodson32
# USER OF INTEREST yoyorune
# BASELINE
# Global user_rating mean = 3.71
# MSE = 0.23
# MAE = 0.40
# Errors within 0.25 = 35.00 %
# Errors within 0.50 = 67.50 %
#
#
# CONTENT BASED FILTERING
# simple - contin. vars only
# FEATURES  ['ABV', 'IBU', 'global_rating']
# TARGET  user_rating
# Percentage of estimators dropped = 0.00 %
# MSE = 0.19
# MAE = 0.33
# Errors within 0.25 = 48.58 %
# Errors within 0.50 = 78.72 %
#
#
# (SEMI) COLD START - COLLABORATIVE FILTERING
# User of Reference for Cosine Sim = yoyorune
# MSE = 0.31
# MAE = 0.34
# Errors within 0.25 = 47.50 %
# Errors within 0.50 = 62.50 %
# HYBRID
#
#
# simple - contin. vars only
# FEATURES  ['ABV', 'IBU', 'global_rating']
#
#
# TARGET  user_rating
#
#
# User of Reference for Cosine Sim = yoyorune
# USER OF INTEREST emichael7390
# BASELINE
# Global user_rating mean = 3.71
# MSE = 0.23
# MAE = 0.40
# Errors within 0.25 = 35.00 %
# Errors within 0.50 = 67.50 %
#
#
# CONTENT BASED FILTERING
# simple - contin. vars only
# FEATURES  ['ABV', 'IBU', 'global_rating']
# TARGET  user_rating
# Percentage of estimators dropped = 33.33 %
# MSE = 0.26
# MAE = 0.42
# Errors within 0.25 = 32.27 %
# Errors within 0.50 = 65.99 %
#
#
# (SEMI) COLD START - COLLABORATIVE FILTERING
# User of Reference for Cosine Sim = emichael7390
# MSE = 0.23
# MAE = 0.28
# Errors within 0.25 = 55.00 %
# Errors within 0.50 = 72.50 %
# HYBRID
#
#
# simple - contin. vars only
# FEATURES  ['ABV', 'IBU', 'global_rating']
#
#
# TARGET  user_rating
#
#
# User of Reference for Cosine Sim = emichael7390
# USER OF INTEREST JandMDAD
# BASELINE
# Global user_rating mean = 3.71
# MSE = 0.23
# MAE = 0.40
# Errors within 0.25 = 35.00 %
# Errors within 0.50 = 67.50 %
#
#
# CONTENT BASED FILTERING
# simple - contin. vars only
# FEATURES  ['ABV', 'IBU', 'global_rating']
# TARGET  user_rating
# Percentage of estimators dropped = 0.00 %
# MSE = 0.56
# MAE = 0.57
# Errors within 0.25 = 25.54 %
# Errors within 0.50 = 51.69 %
#
#
# (SEMI) COLD START - COLLABORATIVE FILTERING
# User of Reference for Cosine Sim = JandMDAD
# MSE = 0.30
# MAE = 0.31
# Errors within 0.25 = 47.50 %
# Errors within 0.50 = 70.00 %
# HYBRID
#
#
# simple - contin. vars only
# FEATURES  ['ABV', 'IBU', 'global_rating']
#
#
# TARGET  user_rating
#
#
# User of Reference for Cosine Sim = JandMDAD
# USER OF INTEREST augustofontes
# BASELINE
# Global user_rating mean = 3.71
# MSE = 0.23
# MAE = 0.40
# Errors within 0.25 = 35.00 %
# Errors within 0.50 = 67.50 %
#
#
# CONTENT BASED FILTERING
# simple - contin. vars only
# FEATURES  ['ABV', 'IBU', 'global_rating']
# TARGET  user_rating
# Percentage of estimators dropped = 33.33 %
# MSE = 0.18
# MAE = 0.33
# Errors within 0.25 = 46.86 %
# Errors within 0.50 = 78.01 %
#
#
# (SEMI) COLD START - COLLABORATIVE FILTERING
# User of Reference for Cosine Sim = augustofontes
# MSE = 0.28
# MAE = 0.34
# Errors within 0.25 = 47.50 %
# Errors within 0.50 = 65.00 %
# HYBRID
#
#
# simple - contin. vars only
# FEATURES  ['ABV', 'IBU', 'global_rating']
#
#
# TARGET  user_rating
#
#
# User of Reference for Cosine Sim = augustofontes
# USER OF INTEREST Slamik
# BASELINE
# Global user_rating mean = 3.71
# MSE = 0.23
# MAE = 0.40
# Errors within 0.25 = 35.00 %
# Errors within 0.50 = 67.50 %
#
#
# CONTENT BASED FILTERING
# simple - contin. vars only
# FEATURES  ['ABV', 'IBU', 'global_rating']
# TARGET  user_rating
# Percentage of estimators dropped = 0.00 %
# MSE = 0.24
# MAE = 0.36
# Errors within 0.25 = 46.06 %
# Errors within 0.50 = 76.35 %
#
#
# (SEMI) COLD START - COLLABORATIVE FILTERING
# User of Reference for Cosine Sim = Slamik
# MSE = 0.37
# MAE = 0.34
# Errors within 0.25 = 47.50 %
# Errors within 0.50 = 67.50 %
# HYBRID
#
#
# simple - contin. vars only
# FEATURES  ['ABV', 'IBU', 'global_rating']
#
#
# TARGET  user_rating
#
#
# User of Reference for Cosine Sim = Slamik
# USER OF INTEREST Newlesha
# BASELINE
# Global user_rating mean = 3.71
# MSE = 0.23
# MAE = 0.40
# Errors within 0.25 = 35.00 %
# Errors within 0.50 = 67.50 %
#
#
# CONTENT BASED FILTERING
# simple - contin. vars only
# FEATURES  ['ABV', 'IBU', 'global_rating']
# TARGET  user_rating
# Percentage of estimators dropped = 33.33 %
# MSE = 0.11
# MAE = 0.26
# Errors within 0.25 = 58.11 %
# Errors within 0.50 = 87.31 %
#
#
# (SEMI) COLD START - COLLABORATIVE FILTERING
# User of Reference for Cosine Sim = Newlesha
# MSE = 0.22
# MAE = 0.33
# Errors within 0.25 = 40.00 %
# Errors within 0.50 = 57.50 %
# HYBRID
#
#
# simple - contin. vars only
# FEATURES  ['ABV', 'IBU', 'global_rating']
#
#
# TARGET  user_rating
#
#
# User of Reference for Cosine Sim = Newlesha

# %%
results = pd.DataFrame.from_dict(d).transpose()
results[['baseline', 'cbf', 'cf', 'hybrid']] = results[['baseline', 'cbf', 'cf', 'hybrid']].astype(float)

# %%
results['hybrid-cf'] = results['hybrid'] - results['cf']

# %%
results
# Out:
#                    baseline       cbf        cf          group    hybrid  \
# Fujimike           0.402524  0.520833  0.325000   low_checkins  0.496172
# insertcoxjokehere  0.402524  0.550046  0.375000   low_checkins  0.304855
# Justinswaldrip     0.402524  0.033443  0.307127   low_checkins  0.086019
# tamarawolfson      0.402524  0.512500  0.300877   low_checkins  0.559833
# marcosten          0.402524  0.413136  0.381250   low_checkins  0.431917
# Audyoh             0.402524  0.437500  0.239255   low_checkins  0.364603
# thomasstorfjord    0.402524  1.434009  0.293750   low_checkins  0.634506
# cmosten            0.402524  0.736042  0.450000   low_checkins  0.554999
# Punk_Caste         0.402524  0.186793  0.387500   low_checkins  0.196507
# WhisKerfuffle      0.402524  0.302228  0.325000   low_checkins  0.460310
# iamthearrison      0.402524  0.621688  0.307127  high_checkins  0.644845
# marcusSRG          0.402524  0.265007  0.400000  high_checkins  0.286015
# thebigjohnson95    0.402524  0.317754  0.362500  high_checkins  0.300209
# dodson32           0.402524  0.257432  0.307127  high_checkins  0.284585
# yoyorune           0.402524  0.330897  0.343750  high_checkins  0.334288
# emichael7390       0.402524  0.422337  0.275000  high_checkins  0.421650
# JandMDAD           0.402524  0.572378  0.313377  high_checkins  0.570790
# augustofontes      0.402524  0.329216  0.337500  high_checkins  0.362834
# Slamik             0.402524  0.356753  0.343750  high_checkins  0.387139
# Newlesha           0.402524  0.256099  0.325000  high_checkins  0.328310
#
#                    hybrid-cf
# Fujimike            0.171172
# insertcoxjokehere  -0.070145
# Justinswaldrip     -0.221108
# tamarawolfson       0.258956
# marcosten           0.050667
# Audyoh              0.125348
# thomasstorfjord     0.340756
# cmosten             0.104999
# Punk_Caste         -0.190993
# WhisKerfuffle       0.135310
# iamthearrison       0.337718
# marcusSRG          -0.113985
# thebigjohnson95    -0.062291
# dodson32           -0.022543
# yoyorune           -0.009462
# emichael7390        0.146650
# JandMDAD            0.257413
# augustofontes       0.025334
# Slamik              0.043389
# Newlesha            0.003310

# %%
results.groupby('group').mean()
# Out:
#                baseline       cbf        cf    hybrid  hybrid-cf
# group
# high_checkins  0.402524  0.372956  0.331513  0.392067   0.060553
# low_checkins   0.402524  0.512653  0.338476  0.408972   0.070496

# %%
results.groupby('group').std()
# Out:
#                baseline       cbf        cf    hybrid  hybrid-cf
# group
# high_checkins       0.0  0.128980  0.034545  0.123033   0.143434
# low_checkins        0.0  0.379462  0.060194  0.172551   0.182780

# %%
results.to_csv("results.csv")
